# %% [markdown]
# # Solving FetchReach with PPO

# %%
#
# Installing Stable Baselines3
#
# !pip install stable-baselines3 gymnasium-robotics mujoco -q
# !apt-get install -y xvfb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import gymnasium as gym
import gymnasium_robotics
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import CheckpointCallback

from gym.wrappers import RecordVideo
from IPython.display import Video
import glob

# %%
print(gym.envs.registry.keys())
print(gym.envs.registry["FetchReach-v3"])
# Out:
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v3', 'LunarLanderContinuous-v3', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v3', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Reacher-v5', 'Pusher-v2', 'Pusher-v4', 'Pusher-v5', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedPendulum-v5', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'InvertedDoublePendulum-v5', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'HalfCheetah-v5', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Hopper-v5', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Swimmer-v5', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Walker2d-v5', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Ant-v5', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'Humanoid-v5', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'HumanoidStandup-v5', 'GymV21Environment-v0', 'GymV26Environment-v0', 'FetchSlide-v1', 'FetchSlide-v3', 'FetchPickAndPlace-v1', 'FetchPickAndPlace-v3', 'FetchReach-v1', 'FetchReach-v3', 'FetchPush-v1', 'FetchPush-v3', 'HandReach-v0', 'HandReach-v2', 'HandManipulateBlockRotateZ-v0', 'HandManipulateBlockRotateZ-v1', 'HandManipulateBlockRotateZ_BooleanTouchSensors-v0', 'HandManipulateBlockRotateZ_BooleanTouchSensors-v1', 'HandManipulateBlockRotateZ_ContinuousTouchSensors-v0', 'HandManipulateBlockRotateZ_ContinuousTouchSensors-v1', 'HandManipulateBlockRotateParallel-v0', 'HandManipulateBlockRotateParallel-v1', 'HandManipulateBlockRotateParallel_BooleanTouchSensors-v0', 'HandManipulateBlockRotateParallel_BooleanTouchSensors-v1', 'HandManipulateBlockRotateParallel_ContinuousTouchSensors-v0', 'HandManipulateBlockRotateParallel_ContinuousTouchSensors-v1', 'HandManipulateBlockRotateXYZ-v0', 'HandManipulateBlockRotateXYZ-v1', 'HandManipulateBlockRotateXYZ_BooleanTouchSensors-v0', 'HandManipulateBlockRotateXYZ_BooleanTouchSensors-v1', 'HandManipulateBlockRotateXYZ_ContinuousTouchSensors-v0', 'HandManipulateBlockRotateXYZ_ContinuousTouchSensors-v1', 'HandManipulateBlockFull-v0', 'HandManipulateBlockFull-v1', 'HandManipulateBlock-v0', 'HandManipulateBlock-v1', 'HandManipulateBlock_BooleanTouchSensors-v0', 'HandManipulateBlock_BooleanTouchSensors-v1', 'HandManipulateBlock_ContinuousTouchSensors-v0', 'HandManipulateBlock_ContinuousTouchSensors-v1', 'HandManipulateEggRotate-v0', 'HandManipulateEggRotate-v1', 'HandManipulateEggRotate_BooleanTouchSensors-v0', 'HandManipulateEggRotate_BooleanTouchSensors-v1', 'HandManipulateEggRotate_ContinuousTouchSensors-v0', 'HandManipulateEggRotate_ContinuousTouchSensors-v1', 'HandManipulateEggFull-v0', 'HandManipulateEggFull-v1', 'HandManipulateEgg-v0', 'HandManipulateEgg-v1', 'HandManipulateEgg_BooleanTouchSensors-v0', 'HandManipulateEgg_BooleanTouchSensors-v1', 'HandManipulateEgg_ContinuousTouchSensors-v0', 'HandManipulateEgg_ContinuousTouchSensors-v1', 'HandManipulatePenRotate-v0', 'HandManipulatePenRotate-v1', 'HandManipulatePenRotate_BooleanTouchSensors-v0', 'HandManipulatePenRotate_BooleanTouchSensors-v1', 'HandManipulatePenRotate_ContinuousTouchSensors-v0', 'HandManipulatePenRotate_ContinuousTouchSensors-v1', 'HandManipulatePenFull-v0', 'HandManipulatePenFull-v1', 'HandManipulatePen-v0', 'HandManipulatePen-v1', 'HandManipulatePen_BooleanTouchSensors-v0', 'HandManipulatePen_BooleanTouchSensors-v1', 'HandManipulatePen_ContinuousTouchSensors-v0', 'HandManipulatePen_ContinuousTouchSensors-v1', 'AntMaze_UMaze-v3', 'AntMaze_Open-v3', 'AntMaze_Open_Diverse_G-v3', 'AntMaze_Open_Diverse_GR-v3', 'AntMaze_Medium-v3', 'AntMaze_Medium_Diverse_G-v3', 'AntMaze_Medium_Diverse_GR-v3', 'AntMaze_Large-v3', 'AntMaze_Large_Diverse_G-v3', 'AntMaze_Large_Diverse_GR-v3', 'AntMaze_UMaze-v4', 'AntMaze_Open-v4', 'AntMaze_Open_Diverse_G-v4', 'AntMaze_Open_Diverse_GR-v4', 'AntMaze_Medium-v4', 'AntMaze_ ...
# EnvSpec(id='FetchReach-v3', entry_point='gymnasium_robotics.envs.fetch.reach:MujocoFetchReachEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=50, order_enforce=True, disable_env_checker=False, kwargs={'reward_type': 'sparse'}, namespace=None, name='FetchReach', version=3, additional_wrappers=(), vector_entry_point=None)

# %%
# Enable EGL rendering
os.environ['MUJOCO_GL'] = 'egl'

# Create and wrap environment
env = gym.make("FetchReach-v3", reward_type="dense", render_mode="rgb_array")

# %%
# Set up callback for saving checkpoints
checkpoint_callback = CheckpointCallback(
    save_freq=50_000,
    save_path='./ppo_checkpoints/',
    name_prefix='ppo_model'
)

# %%
#
# Train the model
#
total_timesteps = 300_000
model = PPO("MultiInputPolicy", env, verbose=1)
model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)

# Save the model
model.save("/content/drive/MyDrive/fetchreach_PPO_model_300k") # it's a zip file
env.close()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 243      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -26.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0050321147 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | -0.0133      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00485     |
# |    std                  | 0.989        |
# |    value_loss           | 12.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -25.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 219          |
# |    iterations           | 3            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0064215437 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.64        |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00689     |
# |    std                  | 0.992        |
# |    value_loss           | 8.39         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -23.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 4           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012445081 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.908       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.985       |
# |    value_loss           | 4.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -21.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 5           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017503556 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.976       |
# |    value_loss           | 3.75        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -19.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 6           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020358691 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0321     |
# |    std                  | 0.968       |
# |    value_loss           | 3.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -18.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 7           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015406532 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.714       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.947       |
# |    value_loss           | 1.65        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -18.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 215        |
# |    iterations           | 8          |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00989996 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.41      |
# |    explained_variance   | 0.761      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.519      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.932      |
# |    value_loss           | 1.12       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -18.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 9           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012209063 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.495       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.917       |
# |    value_loss           | 1.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -18         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 10          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012237246 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.351       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.907       |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -17.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 11          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008631734 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.24       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.405       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0083     |
# |    std                  | 0.894       |
# |    value_loss           | 0.927       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -17.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 12          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007965252 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.357       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00637    |
# |    std                  | 0.886       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -16.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 13          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010874524 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.16       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.392       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.878       |
# |    value_loss           | 0.946       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -15.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 14          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008320663 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.256       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.87        |
# |    value_loss           | 0.608       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -14.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 15          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010922417 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.181       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00817    |
# |    std                  | 0.862       |
# |    value_loss           | 0.468       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -14         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 16          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012111208 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.183       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00779    |
# |    std                  | 0.863       |
# |    value_loss           | 0.434       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -14          |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 215          |
# |    iterations           | 17           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0070934584 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00741     |
# |    std                  | 0.855        |
# |    value_loss           | 0.356        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -13.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 18          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009218847 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0659      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00993    |
# |    std                  | 0.846       |
# |    value_loss           | 0.347       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -13.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 19           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0062878053 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0708       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00697     |
# |    std                  | 0.847        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -13.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 20          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014525474 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.835       |
# |    value_loss           | 0.318       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -12.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 21          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014194255 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0081     |
# |    std                  | 0.826       |
# |    value_loss           | 0.255       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -12.2       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 22          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014843233 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0593      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.815       |
# |    value_loss           | 0.187       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -12         |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 23          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009301206 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0573      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0095     |
# |    std                  | 0.811       |
# |    value_loss           | 0.201       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -11.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 24          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014654573 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0676      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.806       |
# |    value_loss           | 0.185       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -11.2        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 215          |
# |    iterations           | 25           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0103253685 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.76        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0726       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00604     |
# |    std                  | 0.802        |
# |    value_loss           | 0.147        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -10.7       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 26          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014225617 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0549      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.796       |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -10.7       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 27          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009601336 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0813      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00745    |
# |    std                  | 0.79        |
# |    value_loss           | 0.183       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -10.3       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 28          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011693002 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.784       |
# |    value_loss           | 0.164       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -10.2      |
# |    success_rate         | 0.02       |
# | time/                   |            |
# |    fps                  | 215        |
# |    iterations           | 29         |
# |    time_elapsed         | 275        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00798245 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.63      |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.106      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00608   |
# |    std                  | 0.775      |
# |    value_loss           | 0.211      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.87       |
# |    success_rate         | 0.04        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 30          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013332218 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0701      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00964    |
# |    std                  | 0.764       |
# |    value_loss           | 0.178       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.94       |
# |    success_rate         | 0.03        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 31          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012191845 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0474      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.757       |
# |    value_loss           | 0.149       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -9.77        |
# |    success_rate         | 0.02         |
# | time/                   |              |
# |    fps                  | 215          |
# |    iterations           | 32           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0068294555 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0261       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00573     |
# |    std                  | 0.752        |
# |    value_loss           | 0.141        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.69       |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 33          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008830128 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0504      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00506    |
# |    std                  | 0.75        |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.41       |
# |    success_rate         | 0.14        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 34          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008379048 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0545      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00266    |
# |    std                  | 0.737       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.96       |
# |    success_rate         | 0.14        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 35          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010729388 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0796      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 0.737       |
# |    value_loss           | 0.148       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.46       |
# |    success_rate         | 0.11        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 36          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010628207 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0913      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00897    |
# |    std                  | 0.734       |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.95       |
# |    success_rate         | 0.14        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 37          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014040344 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0927      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00753    |
# |    std                  | 0.734       |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.22       |
# |    success_rate         | 0.14        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 38          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009190223 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0463      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00561    |
# |    std                  | 0.734       |
# |    value_loss           | 0.152       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.14       |
# |    success_rate         | 0.12        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 39          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008866889 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0534      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00532    |
# |    std                  | 0.727       |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.81       |
# |    success_rate         | 0.11        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 40          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008218042 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0757      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00453    |
# |    std                  | 0.717       |
# |    value_loss           | 0.13        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -9.03      |
# |    success_rate         | 0.13       |
# | time/                   |            |
# |    fps                  | 216        |
# |    iterations           | 41         |
# |    time_elapsed         | 388        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.00964592 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0507     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00131   |
# |    std                  | 0.714      |
# |    value_loss           | 0.124      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.28       |
# |    success_rate         | 0.14        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 42          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008105123 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0586      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00226     |
# |    std                  | 0.711       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -9.3         |
# |    success_rate         | 0.16         |
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 43           |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0074545746 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0567       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000838    |
# |    std                  | 0.697        |
# |    value_loss           | 0.0862       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.32       |
# |    success_rate         | 0.13        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 44          |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008892489 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0569      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -3.58e-05   |
# |    std                  | 0.691       |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.84       |
# |    success_rate         | 0.11        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 45          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013342049 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0355      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.000695    |
# |    std                  | 0.689       |
# |    value_loss           | 0.102       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.53       |
# |    success_rate         | 0.11        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 46          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011908085 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0669      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00352     |
# |    std                  | 0.687       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -8.55        |
# |    success_rate         | 0.11         |
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 47           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0139065515 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.06        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0237       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000184    |
# |    std                  | 0.683        |
# |    value_loss           | 0.0971       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.85       |
# |    success_rate         | 0.15        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 48          |
# |    time_elapsed         | 455         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012634113 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0564      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00163    |
# |    std                  | 0.678       |
# |    value_loss           | 0.0999      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.64       |
# |    success_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 49          |
# |    time_elapsed         | 464         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.014381858 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0779      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00145    |
# |    std                  | 0.678       |
# |    value_loss           | 0.0891      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | -8.65     |
# |    success_rate         | 0.15      |
# | time/                   |           |
# |    fps                  | 216       |
# |    iterations           | 50        |
# |    time_elapsed         | 473       |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.0117255 |
# |    clip_fraction        | 0.153     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.98     |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.023     |
# |    n_updates            | 490       |
# |    policy_gradient_loss | 0.00187   |
# |    std                  | 0.674     |
# |    value_loss           | 0.0874    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# ...
# |    approx_kl            | 0.010365974 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0196      |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | 0.0034      |
# |    std                  | 0.491       |
# |    value_loss           | 0.0247      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.6        |
# |    success_rate         | 0.26        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 132         |
# |    time_elapsed         | 1244        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.016353417 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0161      |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.000419   |
# |    std                  | 0.484       |
# |    value_loss           | 0.0218      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.51       |
# |    success_rate         | 0.24        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 133         |
# |    time_elapsed         | 1252        |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.027756598 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00148     |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | 0.00189     |
# |    std                  | 0.484       |
# |    value_loss           | 0.0245      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.45       |
# |    success_rate         | 0.26        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 134         |
# |    time_elapsed         | 1262        |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.017037474 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00834    |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.000757   |
# |    std                  | 0.485       |
# |    value_loss           | 0.0298      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.43       |
# |    success_rate         | 0.3         |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 135         |
# |    time_elapsed         | 1272        |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.013342556 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00643     |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.000436   |
# |    std                  | 0.484       |
# |    value_loss           | 0.0278      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.44       |
# |    success_rate         | 0.26        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 136         |
# |    time_elapsed         | 1280        |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.026136195 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | 0.00215     |
# |    std                  | 0.485       |
# |    value_loss           | 0.0245      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.54       |
# |    success_rate         | 0.28        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 137         |
# |    time_elapsed         | 1290        |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.017000696 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0254      |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | 0.00366     |
# |    std                  | 0.481       |
# |    value_loss           | 0.0229      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.58       |
# |    success_rate         | 0.28        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 138         |
# |    time_elapsed         | 1300        |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.016254256 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0209     |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | 0.00398     |
# |    std                  | 0.479       |
# |    value_loss           | 0.0224      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.41       |
# |    success_rate         | 0.22        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 139         |
# |    time_elapsed         | 1308        |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.024402233 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0157      |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | 0.00108     |
# |    std                  | 0.476       |
# |    value_loss           | 0.025       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -8.35      |
# |    success_rate         | 0.19       |
# | time/                   |            |
# |    fps                  | 217        |
# |    iterations           | 140        |
# |    time_elapsed         | 1318       |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.02142946 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.23      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.047      |
# |    n_updates            | 1390       |
# |    policy_gradient_loss | 0.00621    |
# |    std                  | 0.473      |
# |    value_loss           | 0.0236     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.28       |
# |    success_rate         | 0.21        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 141         |
# |    time_elapsed         | 1328        |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.019358672 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0182      |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | 0.00171     |
# |    std                  | 0.467       |
# |    value_loss           | 0.0231      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.07       |
# |    success_rate         | 0.29        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 142         |
# |    time_elapsed         | 1337        |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.016026333 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | 0.000627    |
# |    std                  | 0.466       |
# |    value_loss           | 0.0224      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.31       |
# |    success_rate         | 0.29        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 143         |
# |    time_elapsed         | 1346        |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.018608898 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0223      |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.00271     |
# |    std                  | 0.465       |
# |    value_loss           | 0.023       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.6        |
# |    success_rate         | 0.29        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 144         |
# |    time_elapsed         | 1356        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.011196294 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0215     |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | 0.00205     |
# |    std                  | 0.464       |
# |    value_loss           | 0.0184      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.58       |
# |    success_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 145         |
# |    time_elapsed         | 1365        |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.030066036 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.00294     |
# |    std                  | 0.457       |
# |    value_loss           | 0.0191      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -7.9        |
# |    success_rate         | 0.35        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 146         |
# |    time_elapsed         | 1374        |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.026897123 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0152      |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | 0.00528     |
# |    std                  | 0.457       |
# |    value_loss           | 0.0201      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -8.12        |
# |    success_rate         | 0.32         |
# | time/                   |              |
# |    fps                  | 217          |
# |    iterations           | 147          |
# |    time_elapsed         | 1384         |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0140110105 |
# |    clip_fraction        | 0.221        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0303      |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | 0.00452      |
# |    std                  | 0.455        |
# |    value_loss           | 0.0235       |
# ------------------------------------------

# %%
#
# Evaluate the trained model
#
# Load back model (if necessary)
model = PPO.load("/content/drive/MyDrive/fetchreach_PPO_model_250k")
env = gym.make("FetchReach-v3", reward_type="dense", render_mode=None)

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
print(f"\n[Evaluate_Policy] Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")

env.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [Evaluate_Policy] Mean reward: -8.08 ± 2.53

# %%
# Manual evaluation over 100 episodes with success rate
env = gym.make("FetchReach-v3", reward_type="dense", render_mode=None)
manual_rewards = []

for ep in range(100):
    obs, _ = env.reset()
    done = False
    episode_reward = 0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        episode_reward += reward
    manual_rewards.append(episode_reward)

manual_mean = np.mean(manual_rewards)
manual_std = np.std(manual_rewards)

print(f"[Manual Evaluation] Mean reward: {manual_mean:.2f} ± {manual_std:.2f}")

# Comparison
print("\n--- Comparison ---")
print(f"evaluate_policy(): Mean = {mean_reward:.2f}, Std = {std_reward:.2f}")
print(f"Manual rollout:   Mean = {manual_mean:.2f}, Std = {manual_std:.2f}")

env.close()
# Out:
# [Manual Evaluation] Mean reward: -8.24 ± 2.68
#
# --- Comparison ---
# evaluate_policy(): Mean = -8.08, Std = 2.53
# Manual rollout:   Mean = -8.24, Std = 2.68

# %% [markdown]
# **Video Generation**

# %%
# Simulate one trajectory with video recording
env = gym.make("FetchReach-v3", reward_type="dense", render_mode="rgb_array")
env = RecordVideo(env, video_folder="video", episode_trigger=lambda x: True)

obs, _ = env.reset()
achieved, desired = [], []
total_reward = 0
min_distance = float("inf")

for _ in range(100):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    total_reward += reward

    # Track goals
    ag = obs["achieved_goal"]
    dg = obs["desired_goal"]
    achieved.append(ag)
    desired.append(dg)

    # Compute distance
    dist = np.linalg.norm(ag - dg)
    min_distance = min(min_distance, dist)

    if done:
        break

env.close()

achieved = np.array(achieved)
desired = np.array(desired)
total_dist = np.sum(np.linalg.norm(achieved - desired, axis=1))

print(f"Trajectory total reward = {total_reward:.4f}")
print(f"Total Euclidean distance = {total_dist:.4f}")
print(f"Match: {np.isclose(total_reward, -total_dist)}")
print(f"Minimum distance to goal during trajectory = {min_distance:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/record_video.py:78: UserWarning: WARN: Overwriting existing videos at /content/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Trajectory total reward = -9.5808
# Total Euclidean distance = 9.5808
# Match: True
# Minimum distance to goal during trajectory = 0.0827

# %%
# Display video
mp4list = glob.glob('video/*.mp4')
mp4list.sort()
Video(mp4list[-1], embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
